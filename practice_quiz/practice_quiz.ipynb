# %% [markdown]
# # <span style="color:red"> DATASCI 185 - Practice Quiz </span>

# %% [markdown]
# <font size = "4" >
# This quiz is open book
#
# <br>
#
# - You <span style="color:red"> CAN </span> use all material from the course repo
#
# - You should <span style="color:red"> NOT </span> use other resources outside the course repo.
#
# - You should <span style="color:red"> NOT </span> collaborate with other students
#
# <!-- - Use of LLMs or any AI tools is <span style="color:red"> NOT ALLOWED </span> -->
#
# - AI assistance is <span style="color:red"> NOT </span> permitted for this assignment.
#
# - To get full credit, the code should work as intended. But try to attempt every problem - you can still receive partial credit.
#
# <br>
#
# Print the following string:
#
# "I will abide by Emory's code of conduct"

# %%
print("I will abide by Emory's code of conduct")

# %% [markdown]
# ______________________
#
# <font size = "4">
#
# **Question (A)** Read in data, generate descriptive statistics, create a scatter plot
#
# <font size = "3">
#
# - Using `pandas`, read in the file "features.csv" from the "quiz_data" folder and assign it to a variable named `df`.

# %%
## Your code here
import pandas as pd
df = pd.read_csv('quiz_data/features.csv')

# %% [markdown]
# <font size = "3">
#
# - Using the `.describe` method, generate descriptive statistics for the variable "mpg" and print it to the screen.
#
# - You should **not** explicitly type the string "mpg", and you **should** use the appropriate element from the variable `features_of_interest` defined in the cell below.

# %%
features_of_interest = ["acceleration", "cylinders", "horsepower", "mpg"]

## Your code here
df[features_of_interest[3]].describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %% [markdown]
# <font size = "3">
#
# - Generate a scatter plot of "mpg" vs. "acceleration" for the dataset. ("mpg" should be the x-axis variable.)
#
# - Add labels to both the x and y axes, and add a title to your figure.
#
# - You should **not** explicitly type any part of the strings "mpg" or "acceleration", and you **should** use the variable `features_of_interest` created in the cell above.
#
# - Use `plt.show()` to ensure no extraneous output is printed to the screen.

# %%
# your code here
import matplotlib.pyplot as pt

pt.scatter(x = df[features_of_interest[3]], y = df[features_of_interest[0]], )
pt.xlabel(features_of_interest[3])
pt.ylabel(features_of_interest[0])
pt.show()

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (B)** String concatenation and list indexing
#
# <font size = "3">
#
# The goal of this exercise is to define a variable `message` that contains the string:
#
# <div align="center">"Peter's favorite song: 'More Than This' by Roxy Music" </div>
#
#
# - Change the definition of the variable `message` in the code cell below to coincide with the string mentioned above.
#
# - You should **only** change the line where `message` is defined. You shouldn't create any additional variables.
#
# - You should **not** type any strings explicitly (no using any double or single quotes).
#
# - Remember that `...` (an ellipsis) is just a placeholder for missing or uncompleted code. You should delete the ellipsis from the line of code.

# %%
lst = [" Music", "Peter's favorite song", ": ", "by ",
    "'More Than This'", " ", "Roxy"]

# change the definition of "message" below. ONLY change this line.
message = lst[1] + lst[2] + lst[4] + lst[5] + lst[3] + lst[6] + lst[0]


print(message)
# Out:
# Peter's favorite song: 'More Than This' by Roxy Music

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (C)** Plotting functions with Numpy
#
# <font size = "3">
#
# Using Numpy arrays, create a **line plot** of the function $f(g(t))$, where
#
# $$ f(x) = x^2 - 5x + 2 $$
#
# $$ g(t) = \sin(t + 3) $$
#
# at a set of 75 evenly spaced points in the interval $2\pi \leq t \leq 4\pi$.

# %%
# your code here
import numpy as np
x_vals = np.linspace(-2*np.pi, 4*np.pi, 75)
gx = np.sin(x_vals + 3)
fofg = gx**2 - 5*gx + 2

pt.plot(x_vals,fofg)
pt.xlabel("$x$", fontsize = 16)
pt.ylabel("$f(g(t))$", fontsize = 16)
pt.title("Graph of $y = f(g(t))$ where g(t) = $\\sin(t+3)$ and f(x) = ${x^2 -5x+2}$", fontsize = 12)
pt.show()

#import matplotlib.pyplot as plt 
#x_vals = np.linspace(-3, 3, 75)
#y_vals = 1/(np.sqrt(2*np.pi)) * np.exp(-x_vals**2)

#plt.plot(x_vals, y_vals)
#plt.xlabel("$x$", fontsize = 16)
#plt.ylabel("$y$", fontsize = 16)
#plt.title("Graph of $y = \\frac{1}{\\sqrt{2*pi}}e^{-x^2}$", fontsize = 12)
#plt.show()

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (D)** Variable assignment
#
# <font size = "3">
#
# Does the code below swap the values of a and b? If not, write code that does swap their values.

# %%
a = "left"
b = "right"

b = a 
a = b

# %%
a = "left"
b = "right"
# If the previous cell didn't work, put your changes here:
c = b
b = a
a = c

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (E)** Floating Point equality
#
# <font size = "3">
#
# The next code cell defines two variables (`x` and `y`) that in theory, should be equal. But when the cell is run, it prints out a message saying they are not the same.
#
# How would you choose a different comparison operation between `x` and `y` so that Python prints `True` instead?

# %%
x = 0.1 * 7
y = 0.7

print("x and y are equal:", x == y)


# Your code here - choose a different comparison operator
print("x and y are equal:", type(x) == type(y))
# Out:
# x and y are equal: False
# x and y are equal: True

# %% [markdown]
# _______________________________
# <font size = "4">
#
# **Question (F)** Testing membership in a list
#
# <font size = "3">
#
# The following code cell reads in a text file and converts it to a Python list. The list contains the declared majors of students in DATASCI 185, stored as strings.
#
# Use an appropriate Boolean operation to create a variable with the value `True` if there is a student in the class majoring in Biology, and `False` otherwise. Print its value to the screen.

# %%
# This code reads in a text file and converts it to a Python list
with open("quiz_data/majors.txt") as f:
    majors = [line.strip() for line in f]


# Your code here
print("Biology" in majors)
# Out:
# True
